# %%
from services.ProcessingPipelineService import ProcessingPipelineService

# %%
processing_pipeline_service = ProcessingPipelineService()

random_video_path = "./temp/IMG_h1.MOV"

output_video_path = "./temp/output.mp4"
output_json_path = "./temp/output.json"
output_pdf_path = "./temp/output.pdf"

processing_pipeline_service.analyze_video(
    str(random_video_path),
    str(output_video_path),
    str(output_pdf_path),
    str(output_json_path),
    "handstand",
    "./temp/status.json"
)
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1769178151.087725   44927 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1769178151.110010   45093 gl_context.cc:357] GL version: 3.2 (OpenGL ES 3.2 Mesa 25.0.7-0ubuntu0.24.04.2), renderer: llvmpipe (LLVM 20.1.2, 256 bits)
# /mnt/c/Users/Tofa/source/WorkProjects/GymnasticsAnalysis/Backend/app/services/ClassifyingService.py:461: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   checkpoint = torch.load(path, map_location=self.device)
# INFO: Created TensorFlow Lite XNNPACK delegate for CPU.
# W0000 00:00:1769178151.355127   45061 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1769178152.423650   45060 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# ============================================================
# Initializing Model...
#   - Device: cuda
#   - Num Classes: 4
#   - Window Size: 20
#   - Backbone data_bn: BatchNorm1d(51)
#   - Classification head: Linear(256, 4)
#   - Total parameters: 3,074,312
# Model initialized successfully!
# ============================================================
# Model loaded from ./model_weights/handstand_pyskl_model.pth
# W0000 00:00:1769178177.491127   45056 landmark_projection_calculator.cc:186] Using NORM_RECT without IMAGE_DIMENSIONS is only supported for the square ROI. Provide IMAGE_DIMENSIONS or use PROJECTION_MATRIX.

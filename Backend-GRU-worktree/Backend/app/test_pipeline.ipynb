# %%
import os
from tqdm import tqdm
import random as rnd
import pandas as pd
import seaborn as sns
from services.ProcessingPipelineService import ProcessingPipelineService

# %%
processing_pipeline_service = ProcessingPipelineService()

random_video_path = "./dataset/videos/test/video_2026-01-16_10-25-40.mp4"

output_video_path = "./dataset/videos/test/output.mp4"
output_json_path = "./dataset/videos/test/output.json"
output_pdf_path = "./dataset/videos/test/output.pdf"

processing_pipeline_service.analyze_video(
    str(random_video_path),
    str(output_video_path),
    str(output_pdf_path),
    str(output_json_path),
    "handstand",
    "./dataset/videos/test/status.json"
)
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1768921822.437652  136950 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1768921822.459540  137252 gl_context.cc:357] GL version: 3.2 (OpenGL ES 3.2 Mesa 25.0.7-0ubuntu0.24.04.2), renderer: llvmpipe (LLVM 20.1.2, 256 bits)
# INFO: Created TensorFlow Lite XNNPACK delegate for CPU.
# W0000 00:00:1768921822.721626  137219 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# Model loaded from ./model_weights/scoring_model0/scoring_model_pose_0.pth with input_size None
# Model loaded from ./model_weights/scoring_model0/scoring_model_pose_1.pth with input_size None
# Model loaded from ./model_weights/scoring_model0/scoring_model_pose_3.pth with input_size None
# Model loaded from ./model_weights/scoring_model0/scoring_model_pose_4.pth with input_size None
# Model loaded from ./model_weights/scoring_model0/scoring_model_pose_5.pth with input_size None
# W0000 00:00:1768921823.811436  137216 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1768921823.918217  137226 landmark_projection_calculator.cc:186] Using NORM_RECT without IMAGE_DIMENSIONS is only supported for the square ROI. Provide IMAGE_DIMENSIONS or use PROJECTION_MATRIX.
# /mnt/c/Users/Tofa/source/WorkProjects/GymnasticsAnalysis/Backend-worktree/Backend/app/services/ScoringService.py:286: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at /pytorch/torch/csrc/utils/tensor_new.cpp:253.)
#   padded_sequences = pad_sequence([torch.FloatTensor(s) for s in batch_sequences], batch_first=True)
# [{'label': 'Starting | Score: 0.22', 'segment_scores': {0: 0.22209325432777405, 1: 0.20947669446468353, 2: 0.2275545746088028, 3: 0.22776037454605103, 4: 0.23272421956062317, 5: 0.220396488904953, 6: 0.2202230989933014, 7: 0.25189805030822754, 8: 0.22232145071029663, 9: 0.21071788668632507}}, {'label': 'Starting | Score: 0.22', 'segment_scores': {0: 0.219593346118927, 1: 0.20678289234638214, 2: 0.22469700872898102, 3: 0.22495205700397491, 4: 0.2300020158290863, 5: 0.21790267527103424, 6: 0.21759392321109772, 7: 0.24963907897472382, 8: 0.2195492535829544, 9: 0.20822228491306305}}, {'label': 'Starting | Score: 0.22', 'segment_scores': {0: 0.21793414652347565, 1: 0.20493195950984955, 2: 0.2228277176618576, 3: 0.22303584218025208, 4: 0.22821104526519775, 5: 0.2162354737520218, 6: 0.2158297896385193, 7: 0.24810175597667694, 8: 0.21772685647010803, 9: 0.20652703940868378}}, {'label': 'Starting | Score: 0.22', 'segment_scores': {0: 0.22252781689167023, 1: 0.20989936590194702, 2: 0.22813481092453003, 3: 0.22822754085063934, 4: 0.23330369591712952, 5: 0.22080402076244354, 6: 0.22067572176456451, 7: 0.2522517442703247, 8: 0.22286874055862427, 9: 0.21118615567684174}}, {'label': 'Starting | Score: 0.23', 'segment_scores': {0: 0.22966626286506653, 1: 0.21766464412212372, 2: 0.23634184896945953, 3: 0.2363351434469223, 4: 0.24116677045822144, 5: 0.22793029248714